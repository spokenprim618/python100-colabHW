# %% [markdown]
# <a href="https://colab.research.google.com/github/spokenprim618/python100-colabHW/blob/main/CTD_Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
martj42_international_football_results_from_1872_to_2017_path = kagglehub.dataset_download('martj42/international-football-results-from-1872-to-2017')

print('Data source import complete.')
# Out:
# Using Colab cache for faster access to the 'international-football-results-from-1872-to-2017' dataset.
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/international-football-results-from-1872-to-2017/results.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # TASK 1

# %%
data1 = { 'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'], 'Age': [25, 30, 35, 40, 30], 'Salary': [50000, 60000, 70000, 80000, 55000] }

data2 = { 'Name': ['Frank', 'Grace', 'Helen', 'Ian', 'Jack'], 'Age': [28, 33, 35, 29, 40], 'Salary': [52000, 58000, 72000, 61000, 85000] }
data3 = { 'Name': ['Frank', 'Helen', 'Ian', 'Hima', 'Chaka'], 'Age': [17, 93, 12, 57, 106], 'Favorite Color': ['blue', 'pink', 'burgundy', 'red', 'turquoise'] }
df1 =  pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
df3 = pd.DataFrame(data3)
print(df1['Name'])
print(df1[['Name','Salary']])
print(df1.iloc[:3])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eva
# Name: Name, dtype: object
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   70000
# 3    David   80000
# 4      Eva   55000
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %% [markdown]
# ## TASK 2

# %%
GofAge = df1.groupby('Age')['Salary'].agg(['sum', 'mean', 'count'])
print(GofAge)
# Out:
#         sum     mean  count
# Age
# 25    50000  50000.0      1
# 30   115000  57500.0      2
# 35    70000  70000.0      1
# 40    80000  80000.0      1

# %% [markdown]
# ## TASK 3

# %%
df_1_3_merged = pd.merge(df1, df3, on='Name', how='outer', suffixes=('_left', '_right'))
print(df_1_3_merged)
df_1_3_merged['Salary']=df_1_3_merged['Salary'].fillna(15000)
print(df_1_3_merged)
df_1_3_merged['Favorite Color'] =df_1_3_merged['Favorite Color'].fillna('Yellow')
print(df_1_3_merged)
df_1_3_merged['Age'] = np.where(df_1_3_merged['Age_left'].notna(),df_1_3_merged['Age_left'], df_1_3_merged['Age_right'])
print(df_1_3_merged)
df_1_3_merged.drop(['Age_left','Age_right'], axis=1, inplace=True)
print(df_1_3_merged)

df1_b = df1.copy()
df1_b = df1_b.set_index('Name')
df3_b = df3.copy()
df3_b = df3_b.set_index('Name')
joined_df1_b_df3_b = df1_b.join(df3_b, how='outer',lsuffix='_left', rsuffix='_right')
print(joined_df1_b_df3_b)
# Out:
#       Name  Age_left   Salary  Age_right Favorite Color
# 0    Alice      25.0  50000.0        NaN            NaN
# 1      Bob      30.0  60000.0        NaN            NaN
# 2    Chaka       NaN      NaN      106.0      turquoise
# 3  Charlie      35.0  70000.0        NaN            NaN
# 4    David      40.0  80000.0        NaN            NaN
# 5      Eva      30.0  55000.0        NaN            NaN
# 6    Frank       NaN      NaN       17.0           blue
# 7    Helen       NaN      NaN       93.0           pink
# 8     Hima       NaN      NaN       57.0            red
# 9      Ian       NaN      NaN       12.0       burgundy
#       Name  Age_left   Salary  Age_right Favorite Color
# 0    Alice      25.0  50000.0        NaN            NaN
# 1      Bob      30.0  60000.0        NaN            NaN
# 2    Chaka       NaN  15000.0      106.0      turquoise
# 3  Charlie      35.0  70000.0        NaN            NaN
# 4    David      40.0  80000.0        NaN            NaN
# ...

# %% [markdown]
# ## TASK 4

# %%
filtered_df1 = df1[df1['Age'] > 30]
print(filtered_df1)
# Out:
#       Name  Age  Salary
# 2  Charlie   35   70000
# 3    David   40   80000

# %% [markdown]
# ## TASK 5

# %%
sorted_df1 = df1.sort_values(by='Salary', inplace= False)
sorted_df1.reset_index(inplace=True, drop=True)

print(sorted_df1)
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Eva   30   55000
# 2      Bob   30   60000
# 3  Charlie   35   70000
# 4    David   40   80000

# %% [markdown]
# ## TASK 6

# %%
renamed_df1 = df1.rename(columns={'Age':'Employee Age'}, inplace=False).rename(columns={'Salary':'Employee Salary'}, inplace=False)
print(renamed_df1)
# Out:
#       Name  Employee Age  Employee Salary
# 0    Alice            25            50000
# 1      Bob            30            60000
# 2  Charlie            35            70000
# 3    David            40            80000
# 4      Eva            30            55000

# %% [markdown]
# ## TASK 7

# %%
df1['Salary'] = df1['Salary'] + (df1['Salary']*.1)
print(df1)
# Out:
#       Name  Age   Salary
# 0    Alice   25  55000.0
# 1      Bob   30  66000.0
# 2  Charlie   35  77000.0
# 3    David   40  88000.0
# 4      Eva   30  60500.0

# %% [markdown]
# ## TASK 8

# %%
concat_df1_df2 = pd.concat([df1,df2],ignore_index = True)
print(concat_df1_df2)
# Out:
#       Name  Age   Salary
# 0    Alice   25  55000.0
# 1      Bob   30  66000.0
# 2  Charlie   35  77000.0
# 3    David   40  88000.0
# 4      Eva   30  60500.0
# 5    Frank   28  52000.0
# 6    Grace   33  58000.0
# 7    Helen   35  72000.0
# 8      Ian   29  61000.0
# 9     Jack   40  85000.0

# %% [markdown]
# ## TASK 9

# %%
# Load the CSV file into a DataFrame
football_results = pd.read_csv('/root/.cache/kagglehub/datasets/martj42/international-football-results-from-1872-to-2017/versions/136/results.csv')

# Display the first 5 rows
print(football_results.head(5))

results_1 = football_results[['home_team','away_team','home_score','away_score', 'date']]
print(results_1.head(5))
results_2 = results_1.rename(columns={'home_team':'team'}, inplace=False).rename(columns={'away_team':'opponent'}, inplace=False).rename(columns={'home_score':'points_for'}, inplace=False).rename(columns={'away_score':'points_against'}, inplace=False)
print(results_2.head(5))
results_3 = results_1.rename(columns={'home_team':'opponent'}, inplace=False).rename(columns={'away_team':'team'}, inplace=False).rename(columns={'home_score':'points_against'}, inplace=False).rename(columns={'away_score':'points_for'}, inplace=False)
print(results_3.head(5))
football_results = pd.concat([results_3,results_2], ignore_index=True)
print(football_results.head(5))
points_against = football_results.groupby('team')['points_against'].mean()
points_against.sort_values(ascending= False, inplace = True)
print(points_against.head(10))
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False
#   home_team away_team  home_score  away_score        date
# 0  Scotland   England         0.0         0.0  1872-11-30
# 1   England  Scotland         4.0         2.0  1873-03-08
# 2  Scotland   England         2.0         1.0  1874-03-07
# 3   England  Scotland         2.0         2.0  1875-03-06
# 4  Scotland   England         3.0         0.0  1876-03-04
# ...

# %% [markdown]
# # TASK 10

# %%
football_results = pd.read_csv('/kaggle/input/international-football-results-from-1872-to-2017/results.csv')
Tunisia_home = football_results[football_results['home_team'] == 'Tunisia'][['home_team','away_team','home_score','away_score', 'date']]
Tunisia_away = football_results[football_results['away_team'] == 'Tunisia'][['home_team','away_team','home_score','away_score', 'date']]
Tunisia_team_1 = Tunisia_home.rename(columns={'home_team':'team'}, inplace=False).rename(columns={'away_team':'opponent'}, inplace=False).rename(columns={'home_score':'points_for'}, inplace=False).rename(columns={'away_score':'points_against'}, inplace=False)
Tunisia_team_2 = Tunisia_away.rename(columns={'home_team':'opponent'}, inplace=False).rename(columns={'away_team':'team'}, inplace=False).rename(columns={'home_score':'points_against'}, inplace=False).rename(columns={'away_score':'points_for'}, inplace=False)
Tunisia_teams = pd.concat([Tunisia_team_1,Tunisia_team_2], ignore_index=True)
Tunisia_teams_sorted = Tunisia_teams.sort_values(by='date',ascending= False, inplace = False).reset_index(inplace=False, drop=True)


print(Tunisia_teams_sorted.head(10))
# Out:
#       team     opponent  points_for  points_against        date
# 0  Tunisia  Netherlands         1.0             3.0  2026-06-25
# 1  Tunisia        Japan         0.0             4.0  2026-06-20
# 2  Tunisia       Sweden         1.0             5.0  2026-06-14
# 3  Tunisia      Belgium         0.0             5.0  2026-06-06
# 4  Tunisia      Austria         0.0             1.0  2026-06-01
# 5  Tunisia       Canada         0.0             0.0  2026-03-31
# 6  Tunisia        Haiti         1.0             0.0  2026-03-28
# 7  Tunisia         Mali         1.0             1.0  2026-01-03
# 8  Tunisia     Tanzania         1.0             1.0  2025-12-30
# 9  Tunisia      Nigeria         2.0             3.0  2025-12-27
